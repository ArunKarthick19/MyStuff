# %%
# Basic Libraries
from matplotlib.cbook import boxplot_stats
import numpy as np
import pandas as pd
import seaborn as sb
import seaborn as sns
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
#Importing our csv file
MainData = pd.read_csv('train.csv')
MainData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Dimension of our data
print("Data type : ", type(MainData))
print("Data dims : ", MainData.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1460, 81)

# %%
Q1 = pd.DataFrame(MainData[['LotArea', 'GrLivArea','TotalBsmtSF', 'GarageArea', 'SalePrice']])
Q1.describe()
# Out:
#              LotArea    GrLivArea  TotalBsmtSF   GarageArea      SalePrice
# count    1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    10516.828082  1515.463699  1057.429452   472.980137  180921.195890
# std      9981.264932   525.480383   438.705324   213.804841   79442.502883
# min      1300.000000   334.000000     0.000000     0.000000   34900.000000
# 25%      7553.500000  1129.500000   795.750000   334.500000  129975.000000
# 50%      9478.500000  1464.000000   991.500000   480.000000  163000.000000
# 75%     11601.500000  1776.750000  1298.250000   576.000000  214000.000000
# max    215245.000000  5642.000000  6110.000000  1418.000000  755000.000000

# %%
f = plt.figure(figsize=(15, 4))
sb.boxplot(data=Q1['LotArea'], orient="h")
quartile1 = Q1['LotArea'].quantile(0.25)
quartile3 = Q1['LotArea'].quantile(0.75)
IQR = quartile3 - quartile1 
lower = quartile1 - 1.5 * IQR
upper = quartile3 + 1.5 * IQR
outliers = Q1[(Q1['LotArea'] < lower) | (Q1['LotArea'] > upper)]
num_outliers = len(outliers)
print("Number of outliers:", num_outliers)
# Out:
# Number of outliers: 69

# %%
f = plt.figure(figsize=(15, 4))
sb.boxplot(data=Q1['GrLivArea'], orient="h")
quartile1 = Q1['GrLivArea'].quantile(0.25)
quartile3 = Q1['GrLivArea'].quantile(0.75)
IQR = quartile3 - quartile1 
lower = quartile1 - 1.5 * IQR
upper = quartile3 + 1.5 * IQR
outliers = Q1[(Q1['GrLivArea'] < lower) | (Q1['GrLivArea'] > upper)]
num_outliers = len(outliers)
print("Number of outliers:", num_outliers)
# Out:
# Number of outliers: 31

# %%
f = plt.figure(figsize=(15, 4))
sb.boxplot(data=Q1['TotalBsmtSF'], orient="h")
quartile1 = Q1['TotalBsmtSF'].quantile(0.25)
quartile3 = Q1['TotalBsmtSF'].quantile(0.75)
IQR = quartile3 - quartile1 
lower = quartile1 - 1.5 * IQR
upper = quartile3 + 1.5 * IQR
outliers = Q1[(Q1['TotalBsmtSF'] < lower) | (Q1['TotalBsmtSF'] > upper)]
num_outliers = len(outliers)
print("Number of outliers:", num_outliers)
# Out:
# Number of outliers: 61

# %%
f = plt.figure(figsize=(15, 4))
sb.boxplot(data=Q1['GarageArea'], orient="h")
quartile1 = Q1['GarageArea'].quantile(0.25)
quartile3 = Q1['GarageArea'].quantile(0.75)
IQR = quartile3 - quartile1 
lower = quartile1 - 1.5 * IQR
upper = quartile3 + 1.5 * IQR
outliers = Q1[(Q1['GarageArea'] < lower) | (Q1['GarageArea'] > upper)]
num_outliers = len(outliers)
print("Number of outliers:", num_outliers)
# Out:
# Number of outliers: 21

# %% [markdown]
# <h1>Problem 1(a)<h1>
#     <h2>From the above overservations, LotArea has the maximum number of outliers as per box-plot.It has 69 outliers.<h2>

# %%
f = plt.figure(figsize=(30, 4))
sb.violinplot(data = Q1['LotArea'], orient = "h")
s = Q1['LotArea'].skew()
print ("skew is",s)
# Out:
# skew is 12.207687851233496

# %%
f = plt.figure(figsize=(30, 4))
sb.violinplot(data = Q1['GrLivArea'], orient = "h")
s = Q1['GrLivArea'].skew()
print ("skew is",s)
# Out:
# skew is 1.3665603560164552

# %%
f = plt.figure(figsize=(30, 4))
sb.violinplot(data = Q1['TotalBsmtSF'], orient = "h")
s = Q1['TotalBsmtSF'].skew()
print ("skew is",s)
# Out:
# skew is 1.5242545490627664

# %%
f = plt.figure(figsize=(30, 4))
sb.violinplot(data = Q1['GarageArea'], orient = "h")
s = Q1['GarageArea'].skew()
print ("skew is",s)
# Out:
# skew is 0.17998090674623907

# %% [markdown]
# <h1>Problem 1(b)<h1>
#     <h2>Analysing the violin plots, LotArea is the most skewed from a regular normal distribution. The skew is posetive<h2>

# %%
print(Q1.corr())
sb.heatmap(Q1.corr(), 
           linewidths = 1, annot = True, annot_kws = {"size": 12}, cmap = "Reds")
# Out:
#               LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# LotArea      1.000000   0.263116     0.260833    0.180403   0.263843
# GrLivArea    0.263116   1.000000     0.454868    0.468997   0.708624
# TotalBsmtSF  0.260833   0.454868     1.000000    0.486665   0.613581
# GarageArea   0.180403   0.468997     0.486665    1.000000   0.623431
# SalePrice    0.263843   0.708624     0.613581    0.623431   1.000000
# <Axes: >

# %% [markdown]
# <h1>Problem 1(c)<h1>
#     <h2>From the correlations above, GrLivArea and GarageArea are the two variables that will help us the most in predicting ‘SalePrice’ of houses in this data, since their correlation is the closest to 1.  <h2>

# %%
Q2  = pd.DataFrame(MainData[['MSSubClass', 'Neighborhood', 'BldgType', 'OverallQual', 'SalePrice']])
Q2.describe()
# Out:
#         MSSubClass  OverallQual      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean     56.897260     6.099315  180921.195890
# std      42.300571     1.382997   79442.502883
# min      20.000000     1.000000   34900.000000
# 25%      20.000000     5.000000  129975.000000
# 50%      50.000000     6.000000  163000.000000
# 75%      70.000000     7.000000  214000.000000
# max     190.000000    10.000000  755000.000000

# %%
for Q2N in Q2:
    Q2[Q2N] = Q2[Q2N].astype('category')

# %%
Q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSSubClass    1460 non-null   category
#  1   Neighborhood  1460 non-null   category
#  2   BldgType      1460 non-null   category
#  3   OverallQual   1460 non-null   category
#  4   SalePrice     1460 non-null   category
# dtypes: category(5)
# memory usage: 32.0 KB

# %%
Q2.describe()
# Out:
#         MSSubClass Neighborhood BldgType  OverallQual  SalePrice
# count         1460         1460     1460         1460       1460
# unique          15           25        5           10        663
# top             20        NAmes     1Fam            5     140000
# freq           536          225     1220          397         20

# %%
print("Number of MSSubClass :", len(Q2["MSSubClass"].unique()))
print("Number of Neighborhood :", len(Q2["Neighborhood"].unique()))
print("Number of BldgType :", len(Q2["BldgType"].unique()))
print("Number of OverallQual :", len(Q2["OverallQual"].unique()))
# Out:
# Number of MSSubClass : 15
# Number of Neighborhood : 25
# Number of BldgType : 5
# Number of OverallQual : 10

# %%
print(Q2["MSSubClass"].value_counts())
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64

# %%
print(Q2["Neighborhood"].value_counts())
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64

# %%
print(Q2["BldgType"].value_counts())
# Out:
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64

# %%
print(Q2["OverallQual"].value_counts())
# Out:
# OverallQual
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: count, dtype: int64

# %% [markdown]
# <h1>Problem 2(a),<h1>
#     <h2>From the above details, Neighborhood has the highest number of levels. 1Fam in BldgType has the highest number of houses.<h2>

# %%
Q2B = pd.DataFrame(MainData[['MSSubClass', 'Neighborhood', 'BldgType', 'OverallQual', 'SalePrice']])

# %%
f, axes = plt.subplots(figsize = (20,15))
sb.boxplot(x="MSSubClass", y="SalePrice", data=Q2B)
# Out:
# <Axes: xlabel='MSSubClass', ylabel='SalePrice'>

# %%
f, axes = plt.subplots(figsize = (20,15))
sb.boxplot(x="Neighborhood", y="SalePrice", data=Q2B)
# Out:
# <Axes: xlabel='Neighborhood', ylabel='SalePrice'>

# %%
f, axes = plt.subplots(figsize = (15,10))
sb.boxplot(x="BldgType", y="SalePrice", data=Q2B)
# Out:
# <Axes: xlabel='BldgType', ylabel='SalePrice'>

# %%
f, axes = plt.subplots(figsize = (20,15))
sb.boxplot(x="OverallQual", y="SalePrice", data=Q2B)
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# <h1>Problem 2(b)<h1>
#     <h2>OverallQual and BldgType are the two variables that will help us the most in predicting ‘SalePrice’ of houses in this data.<h2>
#         <h3> OverallQual has a greater range among its levels. The number of outliers are also generally lesser. Thus will help us the most in predicting SalePrice of houses.<h3>
#             <h3>BldgType has lesser ouliers too except for 1Fam(as it has the most houses in it thus making the variable a bit more unpredictable).<h3>
#                 <h3>Thus, BldgType along with OverallQual will help us the most in predicting SalePrice of houses in this data.<h3>

# %%
Q3A = pd.DataFrame(MainData[['GarageType', 'SalePrice']])
Q3A.head()
# Out:
#   GarageType  SalePrice
# 0     Attchd     208500
# 1     Attchd     181500
# 2     Attchd     223500
# 3     Detchd     140000
# 4     Attchd     250000

# %%
Q3A["GarageType"].fillna(value = "NA", inplace = True)
Q3A_encoded = pd.get_dummies(Q3A, columns=['GarageType'])



correlation_matrix = Q3A_encoded.corr()

# Print the correlation matrix
print(correlation_matrix)
sb.heatmap(correlation_matrix.corr(), 
           linewidths = 4, annot = True, annot_kws = {"size": 10}, cmap = "Reds")
# Out:
#                     SalePrice  GarageType_2Types  GarageType_Attchd  \
# SalePrice            1.000000          -0.023974           0.335961
# GarageType_2Types   -0.023974           1.000000          -0.078006
# GarageType_Attchd    0.335961          -0.078006           1.000000
# GarageType_Basment  -0.029425          -0.007376          -0.139437
# GarageType_BuiltIn   0.235449          -0.016269          -0.307537
# GarageType_CarPort  -0.070371          -0.005059          -0.095636
# GarageType_Detchd   -0.354141          -0.038579          -0.729272
# GarageType_NA       -0.236832          -0.015569          -0.294303
#
#                     GarageType_Basment  GarageType_BuiltIn  \
# SalePrice                    -0.029425            0.235449
# GarageType_2Types            -0.007376           -0.016269
# GarageType_Attchd            -0.139437           -0.307537
# GarageType_Basment            1.000000           -0.029081
# ...

# %%
f, axes = plt.subplots(figsize = (20,15))
sb.boxplot(x="GarageType", y="SalePrice", data=Q3A)
# Out:
# <Axes: xlabel='GarageType', ylabel='SalePrice'>

# %% [markdown]
# <h1>Problem 3(a)<h1>
#     <h2>Yes, the SalePrice of the house gets affected by whether it has a Garage or not. In fact the trend seem to show that houses with garages "tends" to have a higher SalePrice. However, we should take note that it is not a very strong trend. If you take a look at Detached and CarPort, they do not show that trend very well, especially the latter. Knowing the type of garage will help predicate the SalePrice better.<h2>
#         <h2>So, we can conclude that the SalePrice of the house would most likely seem to increases in the presence of garage. <h2>
